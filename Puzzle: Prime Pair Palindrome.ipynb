# %% [markdown]
# # Puzzle: Prime Pair Palindrome
#
# Write a program that finds the smallest prime palindrome greater than or equal to a given integer N. A palindrome is a number that reads the same backward as forward. For example, 121 is a palindrome.
#
# You need to find the smallest prime palindrome greater than or equal to N.

# %% [markdown]
# # Don't look at the solution

# %% [markdown]
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!
# - ---> Don't look at the solution !!!

# %%
# First Solution
def PrimePalindrome():
    for i in range(100,1000):
        num_str = str(i)
        if num_str == num_str[::-1]:
            print(f"Ther number is prime Palindrome: {i}")


Pp = PrimePalindrome()
# Out:
# Ther number is prime Palindrome: 101
# Ther number is prime Palindrome: 111
# Ther number is prime Palindrome: 121
# Ther number is prime Palindrome: 131
# Ther number is prime Palindrome: 141
# Ther number is prime Palindrome: 151
# Ther number is prime Palindrome: 161
# Ther number is prime Palindrome: 171
# Ther number is prime Palindrome: 181
# Ther number is prime Palindrome: 191
# Ther number is prime Palindrome: 202
# Ther number is prime Palindrome: 212
# Ther number is prime Palindrome: 222
# Ther number is prime Palindrome: 232
# Ther number is prime Palindrome: 242
# Ther number is prime Palindrome: 252
# Ther number is prime Palindrome: 262
# Ther number is prime Palindrome: 272
# Ther number is prime Palindrome: 282
# Ther number is prime Palindrome: 292
# Ther number is prime Palindrome: 303
# Ther number is prime Palindrome: 313
# Ther number is prime Palindrome: 323
# Ther number is prime Palindrome: 333
# Ther number is prime Palindrome: 343
# ...

# %% [markdown]
# This solution correctly identifies palindromes by checking if the number reads the same backward as forward. However, it doesn't check whether the palindrome is also a prime number.

# %%
# Second Solution

def Primealindrome():
    for i in range(100,1000):
        hunderes = i // 100
        ones = i % 10

        if hunderes == ones:
            print(f'The Number is prime Palindrome:{i}')

Primealindrome()
# Out:
# The Number is prime Palindrome:101
# The Number is prime Palindrome:111
# The Number is prime Palindrome:121
# The Number is prime Palindrome:131
# The Number is prime Palindrome:141
# The Number is prime Palindrome:151
# The Number is prime Palindrome:161
# The Number is prime Palindrome:171
# The Number is prime Palindrome:181
# The Number is prime Palindrome:191
# The Number is prime Palindrome:202
# The Number is prime Palindrome:212
# The Number is prime Palindrome:222
# The Number is prime Palindrome:232
# The Number is prime Palindrome:242
# The Number is prime Palindrome:252
# The Number is prime Palindrome:262
# The Number is prime Palindrome:272
# The Number is prime Palindrome:282
# The Number is prime Palindrome:292
# The Number is prime Palindrome:303
# The Number is prime Palindrome:313
# The Number is prime Palindrome:323
# The Number is prime Palindrome:333
# The Number is prime Palindrome:343
# The Number is prime Palindrome:353
# The Number is prime Palindrome:363
# ...

# %% [markdown]
# This solution attempts to find palindromes by checking if the hundreds digit is equal to the ones digit. However, it also doesn't check whether the palindrome is a prime number.

# %% [markdown]
# To solve the puzzle, you need to combine both conditions: check if the number is a palindrome and if it's also a prime number. Combining these conditions will help you find prime palindromes. I encourage you to continue working on the implementation, and feel free to ask for further assistance if needed!
